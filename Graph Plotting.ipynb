# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('New Text Document.csv')
df.head(10)
# Out:
#    EventIndex  Time  Duration EventType  Accepted  TotalRev  TotalCost  \
# 0           0    10       424    ARRIVE      True   89.4259   237.4428
# 1           1    20       854    ARRIVE      True   47.6278   101.1967
# 2           2    30       920    ARRIVE      True  126.2308   317.9599
# 3           3    40      2341    ARRIVE      True   91.2567   227.6348
# 4           4    50       322    ARRIVE      True   97.9693   316.6412
# 5           5    60      2766    ARRIVE      True   82.3146   321.0862
# 6           6    70       277    ARRIVE      True  144.4226   420.9038
# 7           7    80      1245    ARRIVE      True  118.4724   314.5681
# 8           8    90       339    ARRIVE      True   50.0437   116.6124
# 9           9   100      2022    ARRIVE      True   42.2594    81.1975
#
#    AvgNodeUtilization  AvgLinkUtilization  MIPExecTime  nodeWMappingTime  \
# 0              0.0133              0.0042          0.0                22
# ...

# %%
df.columns
# Out:
# Index(['EventIndex', 'Time', 'Duration', 'EventType', 'Accepted', 'TotalRev',
#        'TotalCost', 'AvgNodeUtilization', 'AvgLinkUtilization', 'MIPExecTime',
#        'nodeWMappingTime', 'linkWMappingTime', 'nodeBMappingTime',
#        'linkBMappingTime', 'Timeout', 'MediumPathLength'],
#       dtype='object')

# %%
df_cost_sorted = df.sort_values(by=['TotalCost'])
df_revenue_sorted = df.sort_values(by=['TotalRev'])

# %%
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(24, 6))

plt.subplot(131)
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[1660:1670], label='DVNMA_NS, r=1:3', marker='v')
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[1680:1690], label='DVNMA_SS, r=1:3', marker='o')
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[1700:1710], label='DVNMA_MS, r=1:3', marker='*')
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[1730:1740], label='DVNMA_NS, r=2:2', marker='v')
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[1740:1750], label='DVNMA_SS, r=2:2', marker='o')
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[1750:1760], label='DVNMA_MS, r=2:2', marker='*')
plt.ylabel('Total Reconfiguration cost', fontsize=15)
plt.xlabel('Virtual Nertwork Size', fontsize=15)
plt.title('Simulations on Net-1, h = 10, f = 1.5.', fontsize=15)
plt.legend()
plt.xlim([3.5, 9])
plt.ylim([244, 256])


plt.subplot(132)
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[2660:2670], label='DVNMA_NS, r=1:3', marker='v')
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[2680:2690], label='DVNMA_SS, r=1:3', marker='o')
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[2700:2710], label='DVNMA_MS, r=1:3', marker='*')
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[2730:2740], label='DVNMA_NS, r=2:2', marker='v')
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[2740:2750], label='DVNMA_SS, r=2:2', marker='o')
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[2750:2760], label='DVNMA_MS, r=2:2', marker='*')
plt.ylabel('Total Reconfiguration cost', fontsize=15)
plt.xlabel('Virtual Nertwork Size', fontsize=15)
plt.title('Simulations on Net-2, r = 3 : 1, f = 1.5', fontsize=15)
plt.legend()
plt.xlim([3.5, 9])
plt.ylim([384, 403])



plt.subplot(133)
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[3660:3670], label='DVNMA_NS, r=1:3', marker='v')
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[3680:3690], label='DVNMA_SS, r=1:3', marker='o')
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[3700:3710], label='DVNMA_MS, r=1:3', marker='*')
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[3730:3740], label='DVNMA_NS, r=2:2', marker='v')
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[3740:3750], label='DVNMA_SS, r=2:2', marker='o')
plt.plot([i for i in range(10)], df_cost_sorted.TotalCost[3750:3760], label='DVNMA_MS, r=2:2', marker='*')
plt.ylabel('Total Reconfiguration cost', fontsize=15)
plt.xlabel('Virtual Nertwork Size', fontsize=15)
plt.title('Simulations on Net-3, r = 3 : 1, f = 1.5', fontsize=15)
plt.legend()
plt.xlim([3.5, 9])
plt.ylim([502, 520])


plt.show()
